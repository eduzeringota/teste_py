# %% [markdown]
# # <font color='blue'>ALPAR - Governo Digital - Processo Inteligente</font>

# %%
import pandas as pd
import numpy as np
import copy
import csv
import codecs

print("pandas versão", pd.__version__)

pd.options.display.max_rows = 2000
# Out:
# pandas versão 1.0.1

# %% [markdown]
# # <font color='black'>trata o dataset total</font>

# %%
# caminho dos arquivos...
caminho = "dados_gd/"

# %%
# abrindo os arquivos...
arq_form = caminho + "form.csv"
arq_sla = caminho + "sla.csv"
arq_tasks = caminho + "tasks.csv"
arq_rating = caminho + "rating.csv"

df_tasks = pd.read_csv(arq_tasks, sep = ',', dtype = str)
print("linhas = %s , colunas = %s " % df_tasks.shape)

# df_tasks
# Out:
# linhas = 414 , colunas = 23

# %%
# exclui colunas não utilizáveis
lst_del = ['Entidade', 'Usuário', 'Grupo', 
           'Motivo de cancelamento', 'Notificação',
           'Comentário', 'Apoio', 'Data e Hora de atendimento',
           'Status externo', 'Data de agendamento', 'Agendamento',
           'Categoria', 'Grupo responsável', 'Prazo (em segundos)']
df_tasks.drop(lst_del, axis=1, inplace=True)
lst_nomes = ['entidade', 'servico', 'protocolo', 'dt_conclusao', 'dt_criacao',
             'acao', 'encaminhado_para', 'encerrado', 'cancelado']
df_tasks.columns = lst_nomes

# %%
# transforma datas do tipo string para tipo data
df_tasks['dt_conclusao']= pd.to_datetime(df_tasks['dt_conclusao'])
df_tasks['dt_criacao']= pd.to_datetime(df_tasks['dt_criacao'])

# %%
# verifica a situação de cada protocolo
df = df_tasks[['protocolo', 'encerrado', 'cancelado']].copy()

df.loc[df['encerrado'] == 'false', 'encerrado'] = 0
df.loc[df['encerrado'] == 'true', 'encerrado'] = 1
df.loc[df['cancelado'] == 'false', 'cancelado'] = 0
df.loc[df['cancelado'] == 'true', 'cancelado'] = 1

df['encerrado'] = pd.to_numeric(df['encerrado'])
df['cancelado'] = pd.to_numeric(df['cancelado'])

# df

# %%
# agrupa por protocolo, obtem o máximo de encerrado e cancelado
df = df.groupby('protocolo').agg({'encerrado': 'max', 'cancelado': 'max'})

# %%
# filtra os protocolos cancelados
df.drop(df[df['cancelado'] == 1].index, inplace=True)

# exclui a coluna de protocolos cancelados
df.drop('cancelado', axis=1, inplace=True)

# cria um dataframe de processos encerrados
df_ence = df[(df['encerrado'] == 1)].copy()

# cria um dataframe de processos em andamento
df_anda = df[(df['encerrado'] == 0)].copy()

# exclui a coluna encerrado dos 2 dataframes
df_ence.drop('encerrado', axis=1, inplace=True)
df_anda.drop('encerrado', axis=1, inplace=True)

# %%
print(df_ence.shape)
print(df_anda.shape)
# Out:
# (19, 0)
# (104, 0)

# %%
# cria o dataframe de encerrados e dataframe de em andamento
lst_ence = df_ence.index.tolist()
lst_anda = df_anda.index.tolist()

# %% [markdown]
# # <font color='black'>cria e trata o dataset de protocolos encerrados</font>

# %%
# cria dataset de tasks encerradas
df_ence = df_tasks[df_tasks['protocolo'].isin(lst_ence)].copy()

# %%
# ordena por entidade, serviço, protocolo, dt_criação
df_ence.sort_values(by = ['entidade', 'servico', 'protocolo', 'dt_criacao'], inplace = True)

# refaz o índice para a nova ordenação
df_ence.reset_index(drop = True, inplace = True)

# %%
# calcula a quantidade de dias da ação e exclui as datas de criação e de conclusão
df_ence['dias'] = (df_ence['dt_conclusao'] - df_ence['dt_criacao']) / np.timedelta64(1, 'D')
df_ence.drop(['dt_conclusao', 'dt_criacao'], axis=1, inplace=True)

# %%
# exclui colunas não utilizáveis
df_ence.drop(['encerrado', 'cancelado'], axis=1, inplace=True)

# df_ence

# %%
# agrupa o dataframe por protocolo, entidade e serviço e cria uma tupla de ações como informação de coluna
df_ence = (df_ence.groupby(['protocolo', 'entidade', 'servico'])
      .agg(
        lst_acao=('acao', lambda x: tuple(x)),
        lst_encaminhado=('encaminhado_para', lambda x: tuple(x)),
        sum_dias=('dias', sum)).reset_index())

# %%
# agrupa o dataframe por protocolo, entidade e serviço e cria uma tupla de ações como informação de coluna
df_ence = (df_ence.groupby(['entidade', 'servico', 'lst_acao', 'lst_encaminhado'])
      .agg(
        media_dias=('sum_dias', 'mean')).reset_index())

# %%
df_ence.shape
# Out:
# (14, 5)

# %% [markdown]
# # <font color='black'>cria o dataset de protocolos em andamento</font>

# %%
# cria dataset de tasks em andamento
df_anda = df_tasks[df_tasks['protocolo'].isin(lst_anda)].copy()

# %%
# exclui colunas não utilizáveis
df_anda.drop(['encerrado', 'cancelado', 'dt_conclusao'], axis=1, inplace=True)

# exclui as linhas com a coluna ação NULL
df_anda = df_anda[~df_anda['acao'].isnull()].copy()

# df_anda

# %%
# ordena por entidade, serviço, protocolo, dt_criação
df_anda.sort_values(by = ['entidade', 'servico', 'protocolo', 'dt_criacao'], inplace = True)

# refaz o índice para a nova ordenação
df_anda.reset_index(drop = True, inplace = True)

# %%
# agrupa o dataframe por protocolo, entidade e serviço e cria uma tupla de ações como informação de coluna
df_anda = (df_anda.groupby(['protocolo', 'entidade', 'servico'])
      .agg(lst_acao=('acao', lambda x: tuple(x)))
      .reset_index()).copy()
# df_anda

# %% [markdown]
# # <font color='black'>cria um arquivo com recomendações</font>

# %%
# analisa cada protocolo em andamento
# procura a sequência do protocolo em andamento para sugerir o restante da sequência

# zera a lista de recomendações
lst_reco = []

# para cada protocolo em andamento procura uma coleção de sequências dos protocolos encerrados
for i in range(len(df_anda)):
    n_acoes = len(df_anda.loc[i, 'lst_acao'])
    df_aux = df_ence[(df_ence['entidade'] == df_anda.loc[i, 'entidade']) & 
                     (df_ence['servico'] == df_anda.loc[i, 'servico']) &
                     (df_ence['lst_acao'].apply(lambda x: x[:n_acoes]) == df_anda.loc[i, 'lst_acao'])]
    df_aux.reset_index(inplace = True)
    
    # zera a variável que vai achar o registro "entidade/serviço" com o menor tempo de conclusão
    # para quando for achado mais de 1 possibilidade
    min_tempo = 9999999999.9
    reco = []
    encaminhado = ''
    
    for k in range(len(df_aux)):
        valor = np.float64(df_aux.loc[k, 'media_dias'])
        if valor < min_tempo:
            min_tempo = valor
            reco = list(df_aux.loc[k, 'lst_acao'])
            encaminhado = df_aux.loc[k, 'lst_encaminhado']
            
    it = {'protocolo': df_anda.loc[i, 'protocolo'],
         'seq_atual': list(df_anda.loc[i, 'lst_acao']),
         'reco_encaminhado_para': encaminhado,
         'reco_seq_recomendada': reco,
         'tempo_medio': min_tempo,
         'reco_acao_idx': len(list(df_anda.loc[i, 'lst_acao']))}
    lst_reco.append(it)

# %%
import json

# grava arquivo de recomendação
y = json.dumps(lst_reco, indent=2, ensure_ascii=False)
print(y)
with open(caminho + 'sugestao.txt', 'w') as outfile:
    json.dump(lst_reco, outfile, indent=2, ensure_ascii=False)
# Out:
# [
#   {
#     "protocolo": "2020.10-32.612",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.10-32.613",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.10-32.614",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.10-32.615",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.10-32.616",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.10-32.617",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Conclusão de Vistoria de Poda"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 5
#   },
#   {
#     "protocolo": "2020.10-32.618",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.10-54.610",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.10-54.611",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-32.549",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-32.570",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-32.571",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-32.572",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Conclusão de Vistoria de Poda",
#       "Solicitação de Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 8
#   },
#   {
#     "protocolo": "2020.7-32.573",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.550",
#     "seq_atual": [
#       "Solicitação",
#       "Inserir Solicitação aos Itens",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.7-34.551",
#     "seq_atual": [
#       "Solicitação",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-34.552",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.553",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Agendamento",
#       "Solicitação de Agendamento",
#       "Solicitação de Agendamento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 4
#   },
#   {
#     "protocolo": "2020.7-34.554",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.555",
#     "seq_atual": [
#       "Solicitação",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-34.556",
#     "seq_atual": [
#       "Solicitação",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-34.557",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Agendamento",
#       "Solicitação de Agendamento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.7-34.558",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.559",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.560",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-34.561",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Abertura de Processo",
#       "Solicitação de Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 5
#   },
#   {
#     "protocolo": "2020.7-34.562",
#     "seq_atual": [
#       "Solicitação",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-34.563",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.564",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.565",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.566",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.567",
#     "seq_atual": [
#       "Solicitação",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-34.568",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.569",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-34.574",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-486.34",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Abertura de Processo",
#       "Abertura de Processo",
#       "Inserir Solicitação aos Itens",
#       "Inserir Solicitação aos Itens"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 9
#   },
#   {
#     "protocolo": "2020.7-489.32",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.7-490.44",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-491.44",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-492.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-493.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-496.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-497.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-501.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-503.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de nomeação do  fiscal"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Gestor Fiscalização",
#       "Fiscal",
#       "Recebimento",
#       "Fiscal",
#       "Pagamento",
#       "Batista",
#       NaN,
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de nomeação do  fiscal",
#       "Oficio de fiscalização",
#       "Oficio de recebimento",
#       "Atestado de recebimento",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Oficio de liquidação e pagamento",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.010093344907407409,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.7-504.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de recebimento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.7-505.48",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-506.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-507.48",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-509.48",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-510.48",
#     "seq_atual": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de nomeação do  fiscal",
#       "Oficio de fiscalização",
#       "Oficio de recebimento",
#       "Atestado de recebimento",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Formalização de  compra e empenho",
#       "Atestado de recebimento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 10
#   },
#   {
#     "protocolo": "2020.7-512.48",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-514.48",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "SALC (Compras)",
#       "Inventário",
#       "Inventário"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Formalização de  compra e empenho",
#       "Oficio de ativação patrimonial"
#     ],
#     "tempo_medio": 0.001558877314814815,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-516.54",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-517.54",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-518.34",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo",
#       "Solicitação de Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.7-520.54",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-526.55",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-527.32",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-529.32",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-532.32",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-533.32",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Apoio"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Livia Oliveira",
#       NaN,
#       "Ouvidoria",
#       "Livia Oliveira",
#       NaN,
#       "Livia Oliveira",
#       NaN,
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Abertura de Processo Administrativo",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Abertura de Processo Administrativo",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 7.997532465277779,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-534.55",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-535.55",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-55.537",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-55.538",
#     "seq_atual": [
#       "Solicitação",
#       "Verificar resultado"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-55.539",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-55.540",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-55.541",
#     "seq_atual": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Verificar resultado"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 5
#   },
#   {
#     "protocolo": "2020.7-55.542",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-55.543",
#     "seq_atual": [
#       "Solicitação",
#       "Verificar resultado"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.7-55.545",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.7-55.546",
#     "seq_atual": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas"
#     ],
#     "reco_encaminhado_para": [
#       "Equipe da Gestão",
#       "Comitê",
#       "Município São José de Ribamar",
#       "Equipe da Gestão",
#       "Equipe da Gestão"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Verificar resultado",
#       "Definir ações ao Município",
#       "Informar ações executadas",
#       "Concluir processo e arquivar"
#     ],
#     "tempo_medio": 0.01370803240740741,
#     "reco_acao_idx": 4
#   },
#   {
#     "protocolo": "2020.7-55.547",
#     "seq_atual": [
#       "Solicitação",
#       "Verificar resultado",
#       "Informar ações executadas"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.8-32.576",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.8-32.577",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.8-32.578",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.8-32.579",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.8-34.575",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Agendamento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.580",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.581",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.9-32.583",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio",
#       "Solicitação de Apoio",
#       "Apoio",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 5
#   },
#   {
#     "protocolo": "2020.9-32.584",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.9-32.586",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-32.587",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-32.588",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.589",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.590",
#     "seq_atual": [
#       "Solicitação",
#       "Apoio"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.591",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-32.592",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-32.593",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 3
#   },
#   {
#     "protocolo": "2020.9-32.594",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.595",
#     "seq_atual": [
#       "Solicitação",
#       "Abertura de Processo Administrativo"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Abertura de Processo Administrativo",
#       "Conclusão de Vistoria de Poda",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 6.730659375,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-32.596",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "Ouvidoria",
#       "Ouvidoria"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Conclusão Atendimento / Arquivamento"
#     ],
#     "tempo_medio": 0.00407447337962963,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-34.582",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Agendamento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-34.609",
#     "seq_atual": [
#       "Solicitação",
#       "Solicitação de Agendamento"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 2
#   },
#   {
#     "protocolo": "2020.9-44.597",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": "",
#     "reco_seq_recomendada": [],
#     "tempo_medio": 9999999999.9,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-59.598",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Análise de Demanda",
#       "BACS - Div de Licitações",
#       "CJU",
#       "BACS - Div de Licitações",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Analisar e Consolidar compra de materiais",
#       "Preparar Edital",
#       "Validar Edital",
#       "Publicar Edital",
#       "Homologar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.011453993055555554,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-59.600",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Análise de Demanda",
#       "BACS - Div de Licitações",
#       "CJU",
#       "BACS - Div de Licitações",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Analisar e Consolidar compra de materiais",
#       "Preparar Edital",
#       "Validar Edital",
#       "Publicar Edital",
#       "Homologar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.011453993055555554,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-59.607",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Análise de Demanda",
#       "BACS - Div de Licitações",
#       "CJU",
#       "BACS - Div de Licitações",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Analisar e Consolidar compra de materiais",
#       "Preparar Edital",
#       "Validar Edital",
#       "Publicar Edital",
#       "Homologar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.011453993055555554,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-59.608",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Análise de Demanda",
#       "BACS - Div de Licitações",
#       "CJU",
#       "BACS - Div de Licitações",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Analisar e Consolidar compra de materiais",
#       "Preparar Edital",
#       "Validar Edital",
#       "Publicar Edital",
#       "Homologar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.011453993055555554,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-60.602",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Empenhar",
#       "Solicitar ao fornecedor",
#       "Pagar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.003008460648148148,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-60.603",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Empenhar",
#       "Solicitar ao fornecedor",
#       "Pagar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.003008460648148148,
#     "reco_acao_idx": 1
#   },
#   {
#     "protocolo": "2020.9-60.604",
#     "seq_atual": [
#       "Solicitação"
#     ],
#     "reco_encaminhado_para": [
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas",
#       "BACS - DAE - Seção de Processamento de Despesas"
#     ],
#     "reco_seq_recomendada": [
#       "Solicitação",
#       "Empenhar",
#       "Solicitar ao fornecedor",
#       "Pagar Fornecedor",
#       "Encerrar e arquivar processo"
#     ],
#     "tempo_medio": 0.003008460648148148,
#     "reco_acao_idx": 1
#   }
# ]
